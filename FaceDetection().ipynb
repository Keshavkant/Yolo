# %% [markdown]
# <a href="https://colab.research.google.com/github/Keshavkant/Yolo/blob/master/FaceDetection().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# [Errno 20] Not a directory: 'darknet'
# /darknet

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# ln: failed to create symbolic link '/mydrive/My Drive': Operation not supported
#  2020-01-21-16-54-28.ba   images		    yolov3
# 'Colab Notebooks'	  Resume_16bec079.pdf	    Yolov3
# 'Copy of obj.names'	  Untitled0.ipynb
# 'Getting started.pdf'	  VID_20200314_160120.mp4

# %%
# !ls /mydrive/yolov3
# Out:
# backup		   obj.data   obj.zip		  yolov3_custom.cfg
# generate_train.py  obj.names  yolov3_custom2.cfg

# %%
# !cp /mydrive/yolov3/obj.zip ../

# %%
# !unzip ../obj.zip -d darknet/data/
# Out:
# Archive:  ../obj.zip
# replace darknet/data/obj/002c4e3ca35ff9f2.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# !cp darknet/cfg/yolov3.cfg /mydrive/yolov3/yolov3_custom2.cfg

# %%
# !cp /mydrive/yolov3/yolov3_custom.cfg ./darknet/cfg

# %%
# !cp /mydrive/yolov3/obj.names ./darknet/data
# !cp /mydrive/yolov3/obj.data  ./darknet/data

# %%
# !cp /mydrive/yolov3/generate_train.py ./

# %%
# !python generate_train.py ./darknet/data

# %%
# !ls darknet/data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     train.txt
# coco.names  goal.txt	 labels			   openimages.names  voc.names
# dog.jpg     horses.jpg	 obj			   person.jpg

# %%
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2020-04-19 16:46:53--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.2’
#
# darknet53.conv.74.2 100%[===================>] 154.96M  1.40MB/s    in 2m 6s
#
# 2020-04-19 16:49:01 (1.23 MB/s) - ‘darknet53.conv.74.2’ saved [162482580/162482580]

# %%
# !./darknet/darknet detector train darknet/data/obj.data darknet/cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 94 Avg (IOU: 0.259216, GIOU: 0.259216), Class: 0.309936, Obj: 0.406717, No Obj: 0.449193, .5R: 0.000000, .75R: 0.000000, count: 2, class_loss = 435.820892, iou_loss = 1.888550, total_loss = 437.709442
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 106 Avg (IOU: 0.455008, GIOU: 0.380477), Class: 0.567190, Obj: 0.417310, No Obj: 0.447807, .5R: 0.250000, .75R: 0.000000, count: 8, class_loss = 1746.952271, iou_loss = 2.906616, total_loss = 1749.858887
# v3 (mse loss, Normalizer: (iou: 0.75, cls: 1.00) Region 82 Avg (IOU: 0.124356, GIOU: 0.124356), Class: 0.343788, Obj: 0.424228, No Obj: 0.504098, .5R: 0.000000, .75R: 0.000000, count: 1, class_loss = 140.157043, iou_loss = 0.486145, total_loss = 140.643188
# ...

# %%
# !./darknet/darknet detector train darknet/data/obj.data darknet/cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# valid: Using default 'darknet/data/train.txt'
# yolov3_custom
#  compute_capability = 600, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# %cd darknet/cfg
# !sed -i 's/batch=64/batch=1/' yolov3_custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov3_custom.cfg
# %cd ..
# Out:
# /darknet/cfg
# /darknet

# %%
# !./darknet detector test data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights /mydrive/images/thermal1.jpg -thresh 0.3
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Couldn't open file: darknet/data/obj.names
